# %%
# Setup Notebook Overview

This notebook prepares the project environment by installing dependencies, setting up directories, and configuring settings. It ensures prerequisites are met for running the main project code, promoting easier maintenance and reproducibility.

- **Execution**: Cells handle specific tasks and can be run individually or collectively. Follow cell comments for instructions and details on each task.
- **Usage**: Execute cells sequentially, adhering to provided instructions.
- **Recommendation**: For best results, use a fresh or virtual environment to prevent conflicts.

Complete all tasks to confidently proceed with the main project code.

# %% [markdown]
# ---
# ## Install Prep

# %%
# Run generate_requirements.py to update the requirements.txt file
# %run generate_requirements.py

# Install the dependencies
# %pip install -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -bb (e:\repos\nba_pistons\.venv\lib\site-packages)

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_properties(0))
print(torch.cuda.get_device_name(0))
print(torch.cuda.current_device())
print(torch.cuda.device_count())
# Out:
# 2.3.1+cu118
# True
# _CudaDeviceProperties(name='NVIDIA GeForce RTX 3070', major=8, minor=6, total_memory=8191MB, multi_processor_count=46)
# NVIDIA GeForce RTX 3070
# 0
# 1

# %% [markdown]
# ---
# # Package Set up **DO NOT TOUCH**

# %%
# %pip install --upgrade pip setuptools wheel build twine
# Out:
# ...
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#    ---------------------------------------- 0.0/54.5 kB ? eta -:--:--
#    ---------------------------------------- 54.5/54.5 kB 2.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/240.7 kB ? eta -:--:--
#    ---------------------------------------- 240.7/240.7 kB 7.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/587.4 kB ? eta -:--:--
#    --------------------------------------- 587.4/587.4 kB 38.5 MB/s eta 0:00:00
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# ...
#    ---------------------------------------- 0.0/579.0 kB ? eta -:--:--
#    --------------------------------------- 579.0/579.0 kB 35.5 MB/s eta 0:00:00
# ...
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -bb (e:\repos\nba_pistons\.venv\lib\site-packages)
# ...

# %%
from setuptools import find_packages

print(find_packages(where='src', include=['nba_analytics', 'nba_analytics.*']))
# Out:
# ['nba_analytics', 'nba_analytics.analytics', 'nba_analytics.cloud', 'nba_analytics.dataset', 'nba_analytics.machine_learning', 'nba_analytics.utils', 'nba_analytics.cloud.azure', 'nba_analytics.cloud.fabric', 'nba_analytics.machine_learning.models']

# %%
# Build distribution
# !build.bat
# Out:
# Cleaning up old build artifacts...
# Building the package...
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools >= 40.8.0
# * Getting build dependencies for sdist...
# running egg_info
# writing src\nba_analytics.egg-info\PKG-INFO
# writing dependency_links to src\nba_analytics.egg-info\dependency_links.txt
# writing requirements to src\nba_analytics.egg-info\requires.txt
# writing top-level names to src\nba_analytics.egg-info\top_level.txt
# reading manifest file 'src\nba_analytics.egg-info\SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE'
# writing manifest file 'src\nba_analytics.egg-info\SOURCES.txt'
# * Building sdist...
# running sdist
# running egg_info
# writing src\nba_analytics.egg-info\PKG-INFO
# writing dependency_links to src\nba_analytics.egg-info\dependency_links.txt
# writing requirements to src\nba_analytics.egg-info\requires.txt
# ...

# %%
# !python -m twine upload dist/*
# !python -m twine upload dist/*
# Out:
# Uploading distributions to https://upload.pypi.org/legacy/
# Uploading nba_analytics-0.2.3-py3-none-any.whl
#
#   0% ---------------------------------------- 0.0/60.5 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/60.5 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/60.5 kB • --:-- • ?
# 100% ---------------------------------------- 60.5/60.5 kB • 00:00 • ?
# 100% ---------------------------------------- 60.5/60.5 kB • 00:00 • ?
# WARNING  Error during upload. Retry with the --verbose option for more details.
# ERROR    HTTPError: 403 Forbidden from https://upload.pypi.org/legacy/
#          Invalid or non-existent authentication information. See
#          https://pypi.org/help/#invalid-auth for more information.
