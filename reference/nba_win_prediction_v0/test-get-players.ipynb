# %%
# %pip install nba_api
# Out:
# ...
#      -------------------------------------- 257.2/257.2 kB 8.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from nba_api.stats.static import teams
from nba_api.stats.endpoints import playercareerstats
from nba_api.live.nba.endpoints import scoreboard

# %%
# Nikola Jokić
career = playercareerstats.PlayerCareerStats(player_id='203999') 

# pandas data frames (optional: pip install pandas)
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203999   2015-16        00  1610612743               DEN        21.0
# 1     203999   2016-17        00  1610612743               DEN        22.0
# 2     203999   2017-18        00  1610612743               DEN        23.0
# 3     203999   2018-19        00  1610612743               DEN        24.0
# 4     203999   2019-20        00  1610612743               DEN        25.0
# 5     203999   2020-21        00  1610612743               DEN        26.0
# 6     203999   2021-22        00  1610612743               DEN        27.0
# 7     203999   2022-23        00  1610612743               DEN        28.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB   REB  AST  STL  BLK  TOV  \
# 0  80  55  1733.0  307  ...   0.811   181   379   560  189   79   50  104
# 1  73  59  2038.0  494  ...   0.825   212   506   718  359   61   55  171
# ...

# %%
# json
career.get_json()
# Out:
# '{"resource": "playercareerstats", "parameters": {"PerMode": "Totals", "PlayerID": 203999, "LeagueID": null}, "resultSets": [{"name": "SeasonTotalsRegularSeason", "headers": ["PLAYER_ID", "SEASON_ID", "LEAGUE_ID", "TEAM_ID", "TEAM_ABBREVIATION", "PLAYER_AGE", "GP", "GS", "MIN", "FGM", "FGA", "FG_PCT", "FG3M", "FG3A", "FG3_PCT", "FTM", "FTA", "FT_PCT", "OREB", "DREB", "REB", "AST", "STL", "BLK", "TOV", "PF", "PTS"], "rowSet": [[203999, "2015-16", "00", 1610612743, "DEN", 21.0, 80, 55, 1733.0, 307, 600, 0.512, 28, 84, 0.333, 154, 190, 0.811, 181, 379, 560, 189, 79, 50, 104, 208, 796], [203999, "2016-17", "00", 1610612743, "DEN", 22.0, 73, 59, 2038.0, 494, 854, 0.578, 45, 139, 0.324, 188, 228, 0.825, 212, 506, 718, 359, 61, 55, 171, 214, 1221], [203999, "2017-18", "00", 1610612743, "DEN", 23.0, 75, 73, 2443.0, 504, 1010, 0.499, 111, 280, 0.396, 266, 313, 0.85, 195, 608, 803, 458, 90, 61, 210, 212, 1385], [203999, "2018-19", "00", 1610612743, "DEN", 24.0, 80, 80, 2504.0, 616, 1206, 0.511
# ...

# %%
# dictionary
career.get_dict()["resultSets"][0]["rowSet"]
# Out:
# [[203999,
#   '2015-16',
#   '00',
#   1610612743,
#   'DEN',
#   21.0,
#   80,
#   55,
#   1733.0,
#   307,
#   600,
#   0.512,
#   28,
#   84,
#   0.333,
#   154,
#   190,
#   0.811,
#   181,
#   379,
#   560,
#   189,
#   79,
#   50,
#   104,
#   208,
#   796],
#  [203999,
#   '2016-17',
#   '00',
#   1610612743,
#   'DEN',
#   22.0,
#   73,
#   59,
#   2038.0,
#   494,
#   854,
#   0.578,
#   45,
#   139,
#   0.324,
#   188,
#   228,
#   0.825,
#   212,
#   506,
#   718,
#   359,
#   61,
#   55,
#   171,
#   214,
#   1221],
#  [203999,
#   '2017-18',
#   '00',
#   1610612743,
#   'DEN',
#   23.0,
#   75,
#   73,
#   2443.0,
#   504,
#   1010,
#   0.499,
#   111,
#   280,
#   0.396,
#   266,
#   313,
#   0.85,
#   195,
#   608,
#   803,
#   458,
#   90,
#   61,
#   210,
#   212,
#   1385],
#  [203999,
#   '2018-19',
#   '00',
#   1610612743,
#   'DEN',
#   24.0,
#   80,
#   80,
#   2504.0,
#   616,
#   1206,
#   0.511,
#   83,
#   270,
#   0.307,
#   289,
#   352,
#   0.821,
# ...

# %%
# json
# games.get_json()
# Out:
# '{"meta": {"version": 1, "request": "https://nba-prod-us-east-1-mediaops-stats.s3.amazonaws.com/NBA/liveData/scoreboard/todaysScoreboard_00.json", "time": "2023-04-30 06:31:25.3125", "code": 200}, "scoreboard": {"gameDate": "2023-04-30", "leagueId": "00", "leagueName": "National Basketball Association", "games": [{"gameId": "0042200201", "gameCode": "20230430/MIANYK", "gameStatus": 3, "gameStatusText": "Final", "period": 4, "gameClock": "", "gameTimeUTC": "2023-04-30T17:00:00Z", "gameEt": "2023-04-30T13:00:00Z", "regulationPeriods": 4, "ifNecessary": false, "seriesGameNumber": "Game 1", "seriesText": "MIA leads 1-0", "seriesConference": "East", "poRoundDesc": "Conf. Semifinals", "gameSubtype": "", "homeTeam": {"teamId": 1610612752, "teamName": "Knicks", "teamCity": "New York", "teamTricode": "NYK", "wins": 0, "losses": 1, "score": 101, "seed": 5, "inBonus": null, "timeoutsRemaining": 0, "periods": [{"period": 1, "periodType": "REGULAR", "score": 32}, {"period": 2, "periodType": "REGU
# ...

# %%
# Today's Score Board
games = scoreboard.ScoreBoard()

# json
games.get_json()

games.get_dict()["scoreboard"]["games"][0]["gameStatus"]

# dictionary
games = [ game for game in games.get_dict()["scoreboard"]["games"] if game["gameStatus"] == 0 ]

# %%
[print(game["gameCode"]) for game in games]

# %%
# Out:
# 20230430/MIANYK
# 20230430/GSWSAC
# [None, None]

# %%
home_team = games[1]["homeTeam"]["teamId"]
away_team = games[1]["awayTeam"]["teamId"]

# %%
home_team
# Out:
# 1610612746

# %%
away_team
# Out:
# 1610612741
